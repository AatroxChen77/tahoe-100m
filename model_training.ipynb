# %% [markdown]
# # Model development
#
# The goal is to train a conditional model that predicts gene expression based on drug, dose, cell line, and mutation profile. We’ll explore generative approaches like variational inference, GANs, or others to build a predictive model that outputs gene expression under perturbed conditions, given expression in a control state.
#
# The core idea is:
#
# Train a model to generate gene expression under perturbation (conditioned on metadata and baseline/control expression).
# Fine-tune the model to adapt to unseen contexts (e.g., normal lung cell types, brain cell types from atlases) using transfer learning.
# Use the adapted model to predict gene expression changes in these new settings.
# Check predictions for expected pathways up-regulated/down-regulated for given drugs (GO analysis and comparison to training set).
# Looking for teammates interested in generative modeling, transfer learning, and gene expression prediction to shape this project together.

# %% [markdown]
# ### Import libraries

# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %% [markdown]
# ### Load the data

# %%
# read the data
adata_tahoe = sc.read_h5ad('/home/ubuntu/anatoly-tahoe-100/data/datatahoe-100m.h5ad')
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata_tahoe.obs
# Out:
#                                  drug    sample   BARCODE_SUB_LIB_ID  \
# 0                  8-Hydroxyquinoline  smp_1783  01_001_052-lib_1105
# 1                  8-Hydroxyquinoline  smp_1783  01_001_105-lib_1105
# 2                  8-Hydroxyquinoline  smp_1783  01_001_165-lib_1105
# 3                  8-Hydroxyquinoline  smp_1783  01_003_094-lib_1105
# 4                  8-Hydroxyquinoline  smp_1783  01_003_164-lib_1105
# ...                               ...       ...                  ...
# 999995  (R)-Verapamil (hydrochloride)  smp_1799  17_160_097-lib_1124
# 999996  (R)-Verapamil (hydrochloride)  smp_1799  17_160_108-lib_1124
# 999997  (R)-Verapamil (hydrochloride)  smp_1799  17_160_112-lib_1124
# 999998  (R)-Verapamil (hydrochloride)  smp_1799  17_160_165-lib_1124
# 999999  (R)-Verapamil (hydrochloride)  smp_1799  17_160_173-lib_1124
#
#        cell_line_id moa-fine  \
# 0         CVCL_0480  unclear
# 1         CVCL_0546  unclear
# 2         CVCL_1717  unclear
# 3         CVCL_1717  unclear
# 4         CVCL_1056  unclear
# ...             ...      ...
# 999995    CVCL_1495  unclear
# 999996    CVCL_1125  unclear
# 999997    CVCL_0320  unclear
# 999998    CVCL_0546  unclear
# 999999    CVCL_1495  unclear
#
#                                          canonical_smiles pubchem_cid   plate  \
# 0                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# 1                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# 2                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# 3                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# 4                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# ...                                                   ...         ...     ...
# 999995  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
# 999996  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
# 999997  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
# 999998  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
# 999999  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
#
#         mean_gene_count_x  mean_tscp_count_x  mean_mread_count_x  \
# 0             1478.268171        2341.339094         2738.463797
# 1             1478.268171        2341.339094         2738.463797
# 2             1478.268171        2341.339094         2738.463797
# 3             1478.268171        2341.339094         2738.463797
# 4             1478.268171        2341.339094         2738.463797
# ...                   ...                ...                 ...
# 999995        1513.610111        2523.233013         2950.299370
# 999996        1513.610111        2523.233013         2950.299370
# 999997        1513.610111        2523.233013         2950.299370
# 999998        1513.610111        2523.233013         2950.299370
# 999999        1513.610111        2523.233013         2950.299370
#
#         mean_pcnt_mito_x                              drugname_drugconc_x  \
# 0               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# 1               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# 2               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# 3               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# 4               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# ...                  ...                                              ...
# 999995          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999996          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999997          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999998          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999999          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
#
#         mean_gene_count_y  mean_tscp_count_y  mean_mread_count_y  \
# 0             1478.268171        2341.339094         2738.463797
# 1             1478.268171        2341.339094         2738.463797
# 2             1478.268171        2341.339094         2738.463797
# 3             1478.268171        2341.339094         2738.463797
# 4             1478.268171        2341.339094         2738.463797
# ...                   ...                ...                 ...
# 999995        1513.610111        2523.233013         2950.299370
# 999996        1513.610111        2523.233013         2950.299370
# 999997        1513.610111        2523.233013         2950.299370
# 999998        1513.610111        2523.233013         2950.299370
# 999999        1513.610111        2523.233013         2950.299370
#
#         mean_pcnt_mito_y                              drugname_drugconc_y
# 0               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# 1               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# 2               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# 3               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# 4               0.023783             [('8-Hydroxyquinoline', 0.05, 'uM')]
# ...                  ...                                              ...
# 999995          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999996          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999997          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999998          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999999          0.069336  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
#
# [1000000 rows x 18 columns]

# %% [markdown]
# ### Encode the data

# %% [markdown]
# ### Train the models

# %% [markdown]
# ### Save results
