# %% [markdown]
# # Data preparation
#
# The aim of this Notebook is to prepare data for downstream processing. In particualr we will load Tahoe dataset, create the hold-outs and save them into the corresponding folders.

# %% [markdown]
# ### Import the libraries

# %%
import scanpy as sc
import numpy as np 
from scanpy import AnnData
from tqdm import tqdm
import ast
import pandas as pd

# %% [markdown]
# ### Create different data splits

# %%
# load the data
adata_full=sc.read_h5ad('/home/ubuntu/anatoly-tahoe-100/data/datatahoe-100m.h5ad')
# Out:
# /home/ubuntu/miniconda3/envs/my_env_model/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %% [markdown]
# ### Create the data slicing

# %%
def safe_parse(val):
    try:
        return ast.literal_eval(val)
    except (ValueError, SyntaxError):
        return None

# %%
# create parsed list
parsed_list = []

# parse the data
for val in adata_full.obs["drugname_drugconc_x"]:
    try:
        parsed = ast.literal_eval(val)
        parsed_list.append(parsed[0])  # Only take the first tuple
    except Exception:
        parsed_list.append((None, None, None))  # Fallback in case of error

# Step 2: Convert to DataFrame
parsed_df = pd.DataFrame(parsed_list, columns=["drug_name", "concentration", "concentration_unit"])

# add the parsed data to the adata
adata_full.obs["drug_name"] = parsed_df["drug_name"].values
adata_full.obs["concentration"] = parsed_df["concentration"].values
adata_full.obs["concentration_unit"] = parsed_df["concentration_unit"].values

# %%
adata_full.obs
# Out:
#                                  drug    sample   BARCODE_SUB_LIB_ID  \
# 0                  8-Hydroxyquinoline  smp_1783  01_001_052-lib_1105
# 1                  8-Hydroxyquinoline  smp_1783  01_001_105-lib_1105
# 2                  8-Hydroxyquinoline  smp_1783  01_001_165-lib_1105
# 3                  8-Hydroxyquinoline  smp_1783  01_003_094-lib_1105
# 4                  8-Hydroxyquinoline  smp_1783  01_003_164-lib_1105
# ...                               ...       ...                  ...
# 999995  (R)-Verapamil (hydrochloride)  smp_1799  17_160_097-lib_1124
# 999996  (R)-Verapamil (hydrochloride)  smp_1799  17_160_108-lib_1124
# 999997  (R)-Verapamil (hydrochloride)  smp_1799  17_160_112-lib_1124
# 999998  (R)-Verapamil (hydrochloride)  smp_1799  17_160_165-lib_1124
# 999999  (R)-Verapamil (hydrochloride)  smp_1799  17_160_173-lib_1124
#
#        cell_line_id moa-fine  \
# 0         CVCL_0480  unclear
# 1         CVCL_0546  unclear
# 2         CVCL_1717  unclear
# 3         CVCL_1717  unclear
# 4         CVCL_1056  unclear
# ...             ...      ...
# 999995    CVCL_1495  unclear
# 999996    CVCL_1125  unclear
# 999997    CVCL_0320  unclear
# 999998    CVCL_0546  unclear
# 999999    CVCL_1495  unclear
#
#                                          canonical_smiles pubchem_cid   plate  \
# 0                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# 1                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# 2                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# 3                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# 4                                C1=CC2=C(C(=C1)O)N=CC=C2      1923.0  plate4
# ...                                                   ...         ...     ...
# 999995  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
# 999996  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
# 999997  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
# 999998  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
# 999999  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...    170014.0  plate4
#
#         mean_gene_count_x  mean_tscp_count_x  ...  mean_pcnt_mito_x  \
# 0             1478.268171        2341.339094  ...          0.023783
# 1             1478.268171        2341.339094  ...          0.023783
# 2             1478.268171        2341.339094  ...          0.023783
# 3             1478.268171        2341.339094  ...          0.023783
# 4             1478.268171        2341.339094  ...          0.023783
# ...                   ...                ...  ...               ...
# 999995        1513.610111        2523.233013  ...          0.069336
# 999996        1513.610111        2523.233013  ...          0.069336
# 999997        1513.610111        2523.233013  ...          0.069336
# 999998        1513.610111        2523.233013  ...          0.069336
# 999999        1513.610111        2523.233013  ...          0.069336
#
#                                     drugname_drugconc_x mean_gene_count_y  \
# 0                  [('8-Hydroxyquinoline', 0.05, 'uM')]       1478.268171
# 1                  [('8-Hydroxyquinoline', 0.05, 'uM')]       1478.268171
# 2                  [('8-Hydroxyquinoline', 0.05, 'uM')]       1478.268171
# 3                  [('8-Hydroxyquinoline', 0.05, 'uM')]       1478.268171
# 4                  [('8-Hydroxyquinoline', 0.05, 'uM')]       1478.268171
# ...                                                 ...               ...
# 999995  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]       1513.610111
# 999996  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]       1513.610111
# 999997  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]       1513.610111
# 999998  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]       1513.610111
# 999999  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]       1513.610111
#
#         mean_tscp_count_y  mean_mread_count_y  mean_pcnt_mito_y  \
# 0             2341.339094         2738.463797          0.023783
# 1             2341.339094         2738.463797          0.023783
# 2             2341.339094         2738.463797          0.023783
# 3             2341.339094         2738.463797          0.023783
# 4             2341.339094         2738.463797          0.023783
# ...                   ...                 ...               ...
# 999995        2523.233013         2950.299370          0.069336
# 999996        2523.233013         2950.299370          0.069336
# 999997        2523.233013         2950.299370          0.069336
# 999998        2523.233013         2950.299370          0.069336
# 999999        2523.233013         2950.299370          0.069336
#
#                                     drugname_drugconc_y  \
# 0                  [('8-Hydroxyquinoline', 0.05, 'uM')]
# 1                  [('8-Hydroxyquinoline', 0.05, 'uM')]
# 2                  [('8-Hydroxyquinoline', 0.05, 'uM')]
# 3                  [('8-Hydroxyquinoline', 0.05, 'uM')]
# 4                  [('8-Hydroxyquinoline', 0.05, 'uM')]
# ...                                                 ...
# 999995  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999996  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999997  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999998  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
# 999999  [('(R)-Verapamil (hydrochloride)', 0.05, 'uM')]
#
#                             drug_name concentration  concentration_unit
# 0                  8-Hydroxyquinoline          0.05                  uM
# 1                  8-Hydroxyquinoline          0.05                  uM
# 2                  8-Hydroxyquinoline          0.05                  uM
# 3                  8-Hydroxyquinoline          0.05                  uM
# 4                  8-Hydroxyquinoline          0.05                  uM
# ...                               ...           ...                 ...
# 999995  (R)-Verapamil (hydrochloride)          0.05                  uM
# 999996  (R)-Verapamil (hydrochloride)          0.05                  uM
# 999997  (R)-Verapamil (hydrochloride)          0.05                  uM
# 999998  (R)-Verapamil (hydrochloride)          0.05                  uM
# 999999  (R)-Verapamil (hydrochloride)          0.05                  uM
#
# [1000000 rows x 21 columns]
